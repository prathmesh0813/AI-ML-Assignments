# %%
university_system = {
    "universities": {
        "GTU_India": {
            "location": "Chennai",
            "ranking": 5,
            "faculties": {
                "engineering": {
                    "dean": "Dr. Narayan",
                    "departments": {
                        "computer_science": {
                            "hod": "Dr. Anish",
                            "labs": {
                                "AI Lab": {
                                    "incharge": "Dr. Meera",
                                    "research_projects": {
                                        "DeepVision": {
                                            "funding": 250000,
                                            "researchers": ["Arjun", "Sneha"],
                                            "status": "ongoing"
                                        },
                                        "RoboMind": {
                                            "funding": 180000,
                                            "researchers": ["Ishita", "Rahul"],
                                            "status": "completed"
                                        }
                                    }
                                },
                                "Systems Lab": {
                                    "incharge": "Dr. Raman",
                                    "research_projects": {
                                        "CloudScale": {
                                            "funding": 300000,
                                            "researchers": ["Karan", "Neha"],
                                            "status": "ongoing"
                                        }
                                    }
                                }
                            },
                            "courses": {
                                "Data Structures": {
                                    "credits": 4,
                                    "students_enrolled": 120
                                },
                                "Machine Learning": {
                                    "credits": 3,
                                    "students_enrolled": 90
                                }
                            }
                        }
                    }
                },
                "management": {
                    "dean": "Dr. Kapoor",
                    "departments": {
                        "finance": {
                            "hod": "Dr. Iyer",
                            "courses": {
                                "Corporate Finance": {
                                    "credits": 3,
                                    "students_enrolled": 80
                                }
                            }
                        }
                    }
                }
            }
        },
        "GTU_Singapore": {
            "location": "Singapore",
            "ranking": 2,
            "faculties": {
                "engineering": {
                    "dean": "Dr. Lee",
                    "departments": {
                        "robotics": {
                            "hod": "Dr. Tan",
                            "labs": {
                                "Automation Lab": {
                                    "incharge": "Dr. Wong",
                                    "research_projects": {
                                        "AutoNav": {
                                            "funding": 400000,
                                            "researchers": ["Jason", "Lily"],
                                            "status": "ongoing"
                                        }
                                    }
                                }
                            }
                        }
                    }
                }
            }
        }
    }
}

# %% [markdown]
# ## Q1. Print the location of GTU_India.
#
# **Answer:**

# %%
# Q1
print(university_system["universities"]["GTU_India"]["location"])
# Out:
# Chennai

# %% [markdown]
# ## Q2. Print the dean of the engineering faculty in GTU_Singapore.
#
# **Answer:**

# %%
# Q2
print(university_system["universities"]["GTU_Singapore"]["faculties"]["engineering"]["dean"])
# Out:
# Dr. Lee

# %% [markdown]
# ## Q3. Print the HOD of the computer_science department.
#
# **Answer:**

# %%
# Q3
print(university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["hod"])
# Out:
# Dr. Anish

# %% [markdown]
# ## Q4. Print all labs under computer_science.
#
# **Answer:**

# %%
# Q4
computer_science = university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]
print(list(computer_science["labs"].keys()))
# Out:
# ['AI Lab', 'Systems Lab']

# %% [markdown]
# ## Q5. Print the funding amount of the "DeepVision" project.
#
# **Answer:**

# %%
# Q5
deepvision = university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["labs"]["AI Lab"]["research_projects"]["DeepVision"]
print(deepvision["funding"])
# Out:
# 250000

# %% [markdown]
# ## Q6. Print all research project names in GTU_India.
#
# **Answer:**

# %%
# Q6
projects = []
for faculty in university_system["universities"]["GTU_India"]["faculties"].values():
    for department in faculty["departments"].values():
        for lab in department.get("labs", {}).values():
            projects.extend(lab.get("research_projects", {}).keys())

print(projects)
# Out:
# ['DeepVision', 'RoboMind', 'CloudScale']

# %% [markdown]
# ## Q7. Print all ongoing projects in GTU_India.
#
# **Answer:**

# %%
# Q7
ongoing_projects = []
for faculty in university_system["universities"]["GTU_India"]["faculties"].values():
    for department in faculty["departments"].values():
        for lab in department.get("labs", {}).values():
            for name, project in lab.get("research_projects", {}).items():
                if project["status"] == "ongoing":
                    ongoing_projects.append(name)

print(ongoing_projects)
# Out:
# ['DeepVision', 'CloudScale']

# %% [markdown]
# ## Q8. Calculate the total funding for all projects in AI Lab.
#
# **Answer:**

# %%
# Q8
ai_lab = university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["labs"]["AI Lab"]
total_funding = sum(
    project["funding"]
    for project in ai_lab["research_projects"].values()
)
print(total_funding)
# Out:
# 430000

# %% [markdown]
# ## Q9. Print all researchers working under Systems Lab.
#
# **Answer:**

# %%
# Q9
systems_lab = university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["labs"]["Systems Lab"]
researchers = []
for project in systems_lab["research_projects"].values():
    researchers.extend(project["researchers"])

print(researchers)
# Out:
# ['Karan', 'Neha']

# %% [markdown]
# ## Q10. Count total students enrolled in all computer_science courses.
#
# **Answer:**

# %%
# Q10
computer_science = university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]
total_students = sum(
    course["students_enrolled"]
    for course in computer_science["courses"].values()
)
print(total_students)
# Out:
# 210

# %% [markdown]
# ## Q11. Print all university names in the system.
#
# **Answer:**

# %%
# Q11
print(list(university_system["universities"].keys()))
# Out:
# ['GTU_India', 'GTU_Singapore']

# %% [markdown]
# ## Q12. Print all faculty names under GTU_India.
#
# **Answer:**

# %%
# Q12
print(list(university_system["universities"]["GTU_India"]["faculties"].keys()))
# Out:
# ['engineering', 'management']

# %% [markdown]
# ## Q13. Print all department names across all universities.
#
# **Answer:**

# %%
# Q13
departments = []
for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        departments.extend(faculty["departments"].keys())

print(departments)
# Out:
# ['computer_science', 'finance', 'robotics']

# %% [markdown]
# ## Q14. Print all deans in the entire system.
#
# **Answer:**

# %%
# Q14
deans = []
for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        deans.append(faculty["dean"])

print(deans)
# Out:
# ['Dr. Narayan', 'Dr. Kapoor', 'Dr. Lee']

# %% [markdown]
# ## Q15. Print all project names across both universities.
#
# **Answer:**

# %%
# Q15
all_projects = []
for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        for department in faculty["departments"].values():
            for lab in department.get("labs", {}).values():
                all_projects.extend(lab.get("research_projects", {}).keys())

print(all_projects)
# Out:
# ['DeepVision', 'RoboMind', 'CloudScale', 'AutoNav']

# %% [markdown]
# ## Q16. Add a new research project under AI Lab.
#
# **Answer:**

# %%
# Q16
ai_lab = university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["labs"]["AI Lab"]

ai_lab["research_projects"]["AIConnect"] = {
    "funding": 200000,
    "researchers": ["Aarav", "Priya"],
    "status": "ongoing"
}

print(ai_lab["research_projects"]["AIConnect"])
# Out:
# {'funding': 200000, 'researchers': ['Aarav', 'Priya'], 'status': 'ongoing'}

# %% [markdown]
# ## Q17. Change the status of "DeepVision" to completed.
#
# **Answer:**

# %%
# Q17
deepvision = university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["labs"]["AI Lab"]["research_projects"]["DeepVision"]
deepvision["status"] = "completed"

print(deepvision)
# Out:
# {'funding': 250000, 'researchers': ['Arjun', 'Sneha'], 'status': 'completed'}

# %% [markdown]
# ## Q18. Increase funding of "CloudScale" by 50,000.
#
# **Answer:**

# %%
# Q18
cloudscale = university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["labs"]["Systems Lab"]["research_projects"]["CloudScale"]
cloudscale["funding"] += 50000

print(cloudscale["funding"])
# Out:
# 350000

# %% [markdown]
# ## Q19. Add a new university to the system.
#
# **Answer:**

# %%
# Q19
university_system["universities"]["GTU_UAE"] = {
    "location": "Dubai",
    "ranking": 8,
    "faculties": {}
}

print(university_system["universities"]["GTU_UAE"])
# Out:
# {'location': 'Dubai', 'ranking': 8, 'faculties': {}}

# %% [markdown]
# ## Q20. Add a new course under finance department.
#
# **Answer:**

# %%
# Q20
finance_department = university_system["universities"]["GTU_India"]["faculties"]["management"]["departments"]["finance"]

finance_department["courses"]["Investment Banking"] = {
    "credits": 3,
    "students_enrolled": 70
}

print(finance_department["courses"]["Investment Banking"])
# Out:
# {'credits': 3, 'students_enrolled': 70}

# %% [markdown]
# ## Q21. Find the project with the highest funding.
#
# **Answer:**

# %%
# Q21
highest_project = None

for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        for department in faculty["departments"].values():
            for lab in department.get("labs", {}).values():
                for name, project in lab.get("research_projects", {}).items():
                    if highest_project is None or project["funding"] > highest_project[1]["funding"]:
                        highest_project = (name, project)

print(highest_project)
# Out:
# ('AutoNav', {'funding': 400000, 'researchers': ['Jason', 'Lily'], 'status': 'ongoing'})

# %% [markdown]
# ## Q22. Find total funding across all universities.
#
# **Answer:**

# %%
# Q22
total_funding = 0

for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        for department in faculty["departments"].values():
            for lab in department.get("labs", {}).values():
                total_funding += sum(
                    project["funding"]
                    for project in lab.get("research_projects", {}).values()
                )

print(total_funding)
# Out:
# 1380000

# %% [markdown]
# ## Q23. Find the university with the best ranking.
#
# **Answer:**

# %%
# Q23
best_university = min(
    university_system["universities"].items(),
    key=lambda item: item[1]["ranking"]
)

print(best_university[0], "-", best_university[1]["ranking"])
# Out:
# GTU_Singapore - 2

# %% [markdown]
# ## Q24. Print all completed projects.
#
# **Answer:**

# %%
# Q24
completed_projects = []

for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        for department in faculty["departments"].values():
            for lab in department.get("labs", {}).values():
                for name, project in lab.get("research_projects", {}).items():
                    if project["status"] == "completed":
                        completed_projects.append(name)

print(completed_projects)
# Out:
# ['DeepVision', 'RoboMind']

# %% [markdown]
# ## Q25. Count total number of researchers in GTU_India.
#
# **Answer:**

# %%
# Q25
researchers = set()

for faculty in university_system["universities"]["GTU_India"]["faculties"].values():
    for department in faculty["departments"].values():
        for lab in department.get("labs", {}).values():
            for project in lab.get("research_projects", {}).values():
                researchers.update(project["researchers"])

print(len(researchers))
# Out:
# 8

# %% [markdown]
# ## Q26. Find which lab has the maximum funding.
#
# **Answer:**

# %%
# Q26
max_lab = None

for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        for department in faculty["departments"].values():
            for lab_name, lab in department.get("labs", {}).items():
                funding = sum(
                    project["funding"]
                    for project in lab.get("research_projects", {}).values()
                )
                if max_lab is None or funding > max_lab[1]:
                    max_lab = (lab_name, funding)

print(max_lab)
# Out:
# ('AI Lab', 630000)

# %% [markdown]
# ## Q27. Print projects grouped by status (ongoing/completed).
#
# **Answer:**

# %%
# Q27
projects_by_status = {
    "ongoing": [],
    "completed": []
}

for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        for department in faculty["departments"].values():
            for lab in department.get("labs", {}).values():
                for name, project in lab.get("research_projects", {}).items():
                    status = project["status"]
                    if status in projects_by_status:
                        projects_by_status[status].append(name)

print(projects_by_status)
# Out:
# {'ongoing': ['AIConnect', 'CloudScale', 'AutoNav'], 'completed': ['DeepVision', 'RoboMind']}

# %% [markdown]
# ## Q28. Print all courses with more than 100 students enrolled.
#
# **Answer:**

# %%
# Q28
courses_over_100 = []

for university in university_system["universities"].values():
    for faculty in university["faculties"].values():
        for department in faculty["departments"].values():
            for course_name, course in department.get("courses", {}).items():
                if course["students_enrolled"] > 100:
                    courses_over_100.append(course_name)

print(courses_over_100)
# Out:
# ['Data Structures']

# %% [markdown]
# ## Q29. Find total number of faculties in the entire system.
#
# **Answer:**

# %%
# Q29
total_faculties = sum(
    len(university["faculties"])
    for university in university_system["universities"].values()
)

print(total_faculties)
# Out:
# 3

# %% [markdown]
# ## Q30. Write a function that searches for a project name and prints its full details.
#
# **Answer:**

# %%
# Q30
def search_project(project_name):
    for university_name, university in university_system["universities"].items():
        for faculty_name, faculty in university["faculties"].items():
            for department_name, department in faculty["departments"].items():
                for lab_name, lab in department.get("labs", {}).items():
                    projects = lab.get("research_projects", {})
                    if project_name in projects:
                        print("University:", university_name)
                        print("Faculty:", faculty_name)
                        print("Department:", department_name)
                        print("Lab:", lab_name)
                        print("Project:", project_name)
                        print("Details:", projects[project_name])
                        return projects[project_name]

    print("Project not found.")
    return None

search_project("DeepVision")
# Out:
# University: GTU_India
# Faculty: engineering
# Department: computer_science
# Lab: AI Lab
# Project: DeepVision
# Details: {'funding': 250000, 'researchers': ['Arjun', 'Sneha'], 'status': 'completed'}
# {'funding': 250000, 'researchers': ['Arjun', 'Sneha'], 'status': 'completed'}
